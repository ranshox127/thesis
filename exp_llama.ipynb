# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from CQ.cq_solver_llama import CQ_Solver_llama, CQ_SYSTEM_PROMPT
from ReAct.react_agent_llama import ReAct_agent, REACT_SYSTEM_PROMPT
from Multi_Agent.mindsearch_llama import MindSearch, PLANNER_SYSTEM_PROMPT

# %%
import json
import os

test_dataset_500 = 'test_dataset_500.json'
if not os.path.exists(test_dataset_500):
    print(f"找不到示範問題檔案: {test_dataset_500}。請先運行之前的程式碼生成該檔案。")
    exit()

with open(test_dataset_500, 'r', encoding='utf-8') as f:
    demo_questions = json.load(f)

# 初始化不同的 Agent 系統和模型


results = []
output_file = 'experiment_results.jsonl'  # 使用 .jsonl 方便逐行寫入 JSON 物件

max_questions = 500

for i, question in enumerate(demo_questions):
    question_id = f"question_{i+1:02d}"  # 使用 3 位數補零，如 question_115
    print(f"\n--- 處理問題: {question_id} ---")

    # react_gpt4o = ReAct_agent(
    #     llm="gpt-4o", system_prompt=REACT_SYSTEM_PROMPT, max_turns=9)
    # react_llama = ReAct_agent(llm="llama 3.3 70B", system_prompt=REACT_SYSTEM_PROMPT, max_turns=9)

    # mindsearch_gpt4o = MindSearch(
    #     llm="gpt-4o", system_prompt=PLANNER_SYSTEM_PROMPT, max_turns=9)
    mindsearch_llama = MindSearch(
        llm="llama 3.3 70B", system_prompt=PLANNER_SYSTEM_PROMPT, max_turns=9)

    # cqsolver_llama = CQ_Solver_llama(llm="llama 3.3 70B", system_prompt=CQ_SYSTEM_PROMPT, max_turns=9, debug_log="llama_debug.log", summary_json="llama_summary.json")

    # systems = {
    #     "ReAct": {"gpt-4o": react_gpt4o, "llama": react_llama},
    #     "MindSearch": {"gpt-4o": mindsearch_gpt4o, "llama": mindsearch_llama},
    #     "CQ_Solver": {"gpt-4o": cqsolver_gpt4o, "llama": cqsolver_llama},
    # }

    systems = {
        # "ReAct": {"llama 3.3 70B": react_llama},
        "MindSearch": {"llama 3.3 70B": mindsearch_llama},
        # "CQ_Solver": {"llama 3.3 70B": cqsolver_llama}
    }

    for system_name, models in systems.items():
        for model_name, agent in models.items():
            print(f"系統: {system_name}, 模型: {model_name}")
            try:
                # 假設每個 Agent 都有一個類似的 run 方法來處理問題
                response = agent.run(question)
                print(f"  回答: {response}")
                result = {
                    "system": system_name,
                    "model": model_name,
                    "question_id": question_id,
                    "question": question,
                    "answer": response,
                    "error": None
                }
            except Exception as e:
                error_message = str(e)
                print(f"  發生錯誤: {error_message}")
                result = {
                    "system": system_name,
                    "model": model_name,
                    "question_id": question_id,
                    "question": question,
                    "answer": None,
                    "error": error_message
                }

            # 即時保存結果
            with open(output_file, 'a', encoding='utf-8') as f:
                json.dump(result, f, ensure_ascii=False)
                f.write('\n')

print(f"\n實驗已完成。結果已保存至 {output_file}")

# %%
import json
import os

test_dataset_500 = 'test_dataset_500.json'
if not os.path.exists(test_dataset_500):
    print(f"找不到示範問題檔案: {test_dataset_500}。請先運行之前的程式碼生成該檔案。")
    exit()

with open(test_dataset_500, 'r', encoding='utf-8') as f:
    demo_questions = json.load(f)

results = []
output_file = 'experiment_results.jsonl'  # 使用 .jsonl 方便逐行寫入 JSON 物件
max_retries = 10

for retry_count in range(1, max_retries + 1):
    print(f"\n--- 第 {retry_count} 次重新嘗試 ---")
    error_entries = []
    updated_entries = []
    original_entries = []

    # 讀取現有的結果並找出錯誤的 'llama 3.3 70B' 回答
    if os.path.exists(output_file):
        with open(output_file, 'r', encoding='utf-8') as f:
            for line in f:
                try:
                    entry = json.loads(line.strip())
                    original_entries.append(entry)
                    if entry.get("model") == "llama 3.3 70B" and entry.get("answer") is None:
                        error_entries.append(entry)
                    else:
                        updated_entries.append(entry) # 先將正確或非目標模型的條目加入待寫回列表
                except json.JSONDecodeError as e:
                    print(f"JSON 解析錯誤: {e}, 行內容: {line.strip()}")

    if not error_entries:
        print("沒有需要重新嘗試的 'llama 3.3 70B' 錯誤回答。")
        break

    print(f"找到 {len(error_entries)} 個需要重新嘗試的錯誤回答。")

    # 重新回答錯誤的條目
    for error_entry in error_entries:
        question_id = error_entry.get("question_id")
        question = error_entry.get("question")
        system_name = error_entry.get("system")
        model_name = error_entry.get("model")

        print(f"\n重新嘗試系統: {system_name}, 問題 ID: {question_id}")

        react_llama = ReAct_agent(
            llm="llama 3.3 70B", system_prompt=REACT_SYSTEM_PROMPT, max_turns=9)
        mindsearch_llama = MindSearch(
            llm="llama 3.3 70B", system_prompt=PLANNER_SYSTEM_PROMPT, max_turns=9)
        cqsolver_llama = CQ_Solver_llama(
            llm="llama 3.3 70B", system_prompt=CQ_SYSTEM_PROMPT,
            max_turns=9, debug_log="llama_debug.log", summary_json="llama_summary.json")

        systems = {
            "ReAct": {"llama 3.3 70B": react_llama},
            "MindSearch": {"llama 3.3 70B": mindsearch_llama},
            "CQ_Solver": {"llama 3.3 70B": cqsolver_llama}
        }

        if system_name in systems and model_name in systems[system_name]:
            agent = systems[system_name][model_name]
            try:
                response = agent.run(question)
                print(f"  重新回答成功: {response}")
                updated_entry = error_entry.copy()
                updated_entry["answer"] = response
                updated_entry["error"] = None # 清除錯誤訊息
                updated_entries.append(updated_entry)
            except Exception as e:
                error_message = str(e)
                print(f"  重新回答失敗: {error_message}")
                updated_entries.append(error_entry) # 保留原來的錯誤條目
        else:
            print(f"  找不到系統 '{system_name}' 或模型 '{model_name}'。")
            updated_entries.append(error_entry) # 保留原來的錯誤條目

    # 寫回更新後的結果 (覆蓋原檔案)
    with open(output_file, 'w', encoding='utf-8') as f:
        for entry in updated_entries:
            json.dump(entry, f, ensure_ascii=False)
            f.write('\n')

print("\n重新嘗試過程結束。")

# %%
import json
import os

# === 檔案路徑 ===
experiment_input = 'experiment_results.jsonl'
output_file = 'llama_experiment_results_makeup_exam2.jsonl'

specified_question_id = ['question_02', 'question_03', 'question_04', 'question_07', 'question_10', 'question_13', 'question_18', 'question_19', 'question_21', 'question_22', 'question_24', 'question_25', 'question_28', 'question_31', 'question_32', 'question_36', 'question_38', 'question_39', 'question_40', 'question_43', 'question_48', 'question_50', 'question_52', 'question_54', 'question_56', 'question_61', 'question_62', 'question_65', 'question_70', 'question_71', 'question_72', 'question_73', 'question_76', 'question_77', 'question_83', 'question_87', 'question_89', 'question_91', 'question_92', 'question_93', 'question_96', 'question_100', 'question_102', 'question_103', 'question_104', 'question_106', 'question_107', 'question_108', 'question_109', 'question_110', 'question_111', 'question_113', 'question_116', 'question_118', 'question_119', 'question_121', 'question_122', 'question_124', 'question_126', 'question_127', 'question_128', 'question_131', 'question_133', 'question_134', 'question_135', 'question_136', 'question_137', 'question_138', 'question_139', 'question_141', 'question_142', 'question_143', 'question_144', 'question_145', 'question_147', 'question_152', 'question_153', 'question_154', 'question_155', 'question_159', 'question_160', 'question_165', 'question_167', 'question_168', 'question_172', 'question_174', 'question_177', 'question_182', 'question_183', 'question_184', 'question_189', 'question_192', 'question_193', 'question_194', 'question_199', 'question_200', 'question_203', 'question_209', 'question_210', 'question_211', 'question_214', 'question_215', 'question_217', 'question_218', 'question_221', 'question_222', 'question_224', 'question_227', 'question_230', 'question_231', 'question_232', 'question_234', 'question_235', 'question_237', 'question_238', 'question_241', 'question_243', 'question_245', 'question_246', 'question_247', 'question_249', 'question_251', 'question_252', 'question_254', 'question_255', 'question_257', 'question_259', 'question_260', 'question_262', 'question_264', 'question_265', 'question_266', 'question_269', 'question_270', 'question_271', 'question_272', 'question_275', 'question_276', 'question_278', 'question_279', 'question_280',
                         'question_281', 'question_282', 'question_283', 'question_286', 'question_287', 'question_293', 'question_294', 'question_298', 'question_299', 'question_300', 'question_301', 'question_302', 'question_305', 'question_306', 'question_307', 'question_308', 'question_309', 'question_310', 'question_311', 'question_312', 'question_313', 'question_315', 'question_316', 'question_318', 'question_319', 'question_320', 'question_321', 'question_322', 'question_324', 'question_325', 'question_326', 'question_328', 'question_331', 'question_332', 'question_335', 'question_338', 'question_343', 'question_344', 'question_345', 'question_349', 'question_351', 'question_352', 'question_353', 'question_354', 'question_356', 'question_357', 'question_358', 'question_361', 'question_362', 'question_363', 'question_365', 'question_370', 'question_371', 'question_373', 'question_375', 'question_376', 'question_380', 'question_383', 'question_385', 'question_387', 'question_388', 'question_391', 'question_395', 'question_396', 'question_397', 'question_399', 'question_402', 'question_403', 'question_405', 'question_406', 'question_407', 'question_408', 'question_409', 'question_411', 'question_414', 'question_415', 'question_418', 'question_419', 'question_422', 'question_428', 'question_429', 'question_430', 'question_431', 'question_432', 'question_433', 'question_438', 'question_441', 'question_442', 'question_444', 'question_445', 'question_446', 'question_447', 'question_448', 'question_449', 'question_451', 'question_454', 'question_456', 'question_459', 'question_460', 'question_461', 'question_463', 'question_465', 'question_468', 'question_472', 'question_474', 'question_476', 'question_480', 'question_481', 'question_482', 'question_485', 'question_487', 'question_489', 'question_490', 'question_492', 'question_493', 'question_494', 'question_496', 'question_497', 'question_498', 'question_41', 'question_53', 'question_55', 'question_90', 'question_97', 'question_188', 'question_196', 'question_206', 'question_212', 'question_216', 'question_334', 'question_336', 'question_382', 'question_390', 'question_393', 'question_410', 'question_417', 'question_466', 'question_475', 'question_163', 'question_66', 'question_125']

question_lookup = {}

if not os.path.exists(experiment_input):
    print(f"找不到原始結果檔案: {experiment_input}")
    exit()

with open(experiment_input, 'r', encoding='utf-8') as f:
    for line in f:
        entry = json.loads(line)
        qid = entry.get("question_id")
        question = entry.get("question")
        if qid and question:
            question_lookup[qid] = question

# === 重新跑的目標問題 ===
target_questions = []

for qid in specified_question_id:
    if qid in question_lookup:
        target_questions.append((qid, question_lookup[qid]))
    else:
        print(f"⚠️ 找不到對應內容: {qid}")


# === 開始執行實驗 ===
for question_id, question in target_questions:
    print(f"\n--- 重新處理問題: {question_id} ---")

    cqsolver_gpt4o = CQ_Solver_llama(
        llm="llama 3.3 70B",
        system_prompt=CQ_SYSTEM_PROMPT,
        max_turns=9,
        summary_json="llama_CQ_Solver_summary_makeup2.json"
    )

    system_name = "CQ_Solver"
    model_name = "llama 3.3 70B"

    try:
        response = cqsolver_gpt4o.run(question)
        print(f"  ✅ 回答: {response}")
        result = {
            "system": system_name,
            "model": model_name,
            "question_id": question_id,
            "question": question,
            "answer": response,
            "error": None
        }
    except Exception as e:
        error_message = str(e)
        print(f"  💥 發生錯誤: {error_message}")
        result = {
            "system": system_name,
            "model": model_name,
            "question_id": question_id,
            "question": question,
            "answer": None,
            "error": error_message
        }

    # === 即時寫入結果 ===
    with open(output_file, 'a', encoding='utf-8') as f_out:
        json.dump(result, f_out, ensure_ascii=False)
        f_out.write('\n')

print("\n✅ 重新處理指定問題已完成。結果已更新至 llama_experiment_results_makeup_exam2.jsonl")
# Out:
# --- 重新處理問題: question_02 ---
# Error processing https://www.thoughtco.com/increased-minimum-wage-impact-4019618: HTTPSConnectionPool(host='www.thoughtco.com', port=443): Read timed out. (read timeout=5)
# Error processing https://www.investopedia.com/ask/answers/052815/does-raising-minimum-wage-increase-inflation.asp: HTTPSConnectionPool(host='www.investopedia.com', port=443): Read timed out. (read timeout=5)
#   ✅ 回答: The minimum wage increases due to a combination of factors including economic growth, inflation, geographical differences, and the need to maintain the purchasing power of low-wage workers. The main factors contributing to minimum wage increases are interconnected and influenced by various economic and social conditions. Inflation, in particular, plays a critical role as it directly affects the purchasing power of the minimum wage, necessitating adjustments to protect the standard of living of low-wage workers. Understanding these causes is essential for assessing the effects of minimum wage increases and for policymakers to make informed decisions that balance the needs of workers, employers, and the overall economy.
#
# --- 重新處理問題: question_03 ---
#   ✅ 回答: The role of an organizational culture during a change management program is multifaceted and critically important. It significantly influences employee engagement, which is a key determinant of the success of the change program. Organizational culture affects how employees perceive, adapt to, and engage with the change process. A culture that fosters open communication, transparency, employee empowerment, and involvement in the change process is more likely to experience higher levels of employee engagement and commitment to the change efforts. Effective leadership is also crucial, as leaders must communicate the vision for change clearly, embody the desired cultural values, and empower employees to take ownership of their roles in the change process. Moreover, strategic alignment of the organizational culture with the change management goals is essential. This involves assessing the current culture, defining a clear vision for the desired culture, setting specific goals for cultural change, and implementing strategies such as training, open communication, and employee involvement to achieve these goals. By understanding the impact of organizational culture on employee engagement and implementing effective strategies for cultural alignment, organizations can navigate the challenges of change management more successfully, ensuring a smoother transition and achieving the desired outcomes of the change program.
#
# --- 重新處理問題: question_04 ---
#   ✅ 回答: The Data Protection Act has a profound impact on individuals by safeguarding their personal data and offering them control over its usage, thereby fostering trust in data-driven processes and shielding against data abuse. The act's regulatory framework imposes strict obligations on organizations, ensuring they handle personal data transparently, securely, and with respect for individuals' rights, thus promoting a culture of data protection and accountability. Individuals' rights, including access, rectification, erasure, objection, and restriction of processing, are cornerstone in enabling them to manage their personal data and ensure it is handled lawfully.
#
# --- 重新處理問題: question_07 ---
#   ✅ 回答: The impact of technology on labor-management relations is complex and multifaceted. Technology influences labor-management relations through primary channels such as digital communication tools, artificial intelligence, and automation. These advancements require employers to adapt their strategies to prioritize transparency, worker involvement, and compliance with labor laws. Furthermore, technological changes necessitate a shift in worker skills, with a focus on digital literacy, critical thinking, and problem-solving abilities. This shift requires continuous learning and reskilling, with both employers and unions playing a crucial role in supporting workforce development. Labor unions are adapting to technological changes by negotiating for consultation rights, economic security, and protection from job displacement, thereby demonstrating the evolving nature of labor-management negotiations. Overall, understanding these channels and adaptations is essential for clarifying the scope of technological impact on labor-management relations and for developing effective strategies to navigate these changes.
#
# --- 重新處理問題: question_10 ---
# Error processing https://www.unesco.org/en/articles/world-education-statistics-2024: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ✅ 回答: The comparison of American education to the world is a complex and multifaceted issue. American education ranks around the middle globally in terms of literacy and numeracy, with the United States ranking 38th out of 71 countries in math and 24th in science according to the Program for International Student Assessment (PISA) in 2015. The Trends in International Mathematics and Science Study (TIMSS) also showed that the U.S. had lower average scores in math and science compared to other countries. However, the U.S. has a higher percentage of students from socio-economically advantaged backgrounds, which may affect its ranking.
#
# Socio-economic factors significantly influence educational outcomes in the US, often resulting in lower literacy levels and limited access to quality education for disadvantaged students. Targeted interventions are necessary to reduce the achievement gap.
#
# International assessments like PISA, TIMSS, and PIRLS provide valuable insights into educational outcomes, but their limitations must be considered. Understanding the methodologies and limitations of these assessments is crucial for interpreting their results accurately. Bayesian approaches can provide a more nuanced analysis, informing educational policy and practice decisions.
#
# Key metrics used to compare education systems worldwide include average scores on international assessments, literacy rates, graduation rates, and student-teacher ratios. These metrics provide a comprehensive overview of a country's education system, allowing for comparisons across different countries and regions.
#
# In conclusion, American education faces challenges in terms of literacy and numeracy, and socio-economic factors play a significant role in educational outcomes. However, by understanding the methodologies and limitations of international assessments and using targeted interventions to support disadvantaged students, the US can work towards improving its education system and reducing the achievement gap.
#
# --- 重新處理問題: question_13 ---
#   ✅ 回答: The fuel shortage is primarily attributed to a combination of supply chain disruptions and geopolitical events. Supply chain issues, including logistics and transportation problems, semiconductor shortages, pandemic-related restrictions, and labor shortages, have significantly contributed to the shortage. These disruptions have led to delays and increased costs in the supply chain, ultimately affecting the availability of fuel. Furthermore, recent geopolitical events, such as trade wars and tensions between the US and countries like Canada, Russia, and Iran, have introduced uncertainty into the oil market, potentially impacting fuel supply and prices. Notably, there has been no significant increase in demand for fuel prior to the shortage, with the U.S. Energy Information Administration even forecasting a decrease in gasoline consumption in 2026 due to rising vehicle fleet efficiency. Therefore, the fuel shortage can be largely attributed to these logistical and geopolitical factors, rather than an increase in demand.
#
# --- 重新處理問題: question_18 ---
# Error processing https://elevatethatmindset.com/roots-morality-culture-society-shape-ethics/: HTTPSConnectionPool(host='elevatethatmindset.com', port=443): Max retries exceeded with url: /roots-morality-culture-society-shape-ethics/ (Caused by SSLError(SSLError(1, '[SSL: TLSV1_UNRECOGNIZED_NAME] tlsv1 unrecognized name (_ssl.c:1006)')))
#   ✅ 回答: Ethics is determined by a complex interplay of factors, including cultural norms, personal experiences, and religious beliefs. Cultural norms significantly influence moral values and principles, with different cultures having unique ethical frameworks such as the Ethics of Autonomy, Community, and Divinity. These frameworks represent how societies view morality, with cultural relativism and moral universalism being two perspectives that shape ethical decision-making. Cultural relativism argues that moral values are culturally specific, while moral universalism believes in core moral values that apply to everyone. Education, family, and social institutions play a crucial role in transmitting cultural values to the next generation, and globalization has led to the blending of diverse moral values. Personal experiences can also significantly shape an individual's ethical framework by influencing their moral development, values, and decision-making processes. According to Lawrence Kohlberg's model of moral development, individuals progress through stages of moral reasoning, with higher stages associated with more ethical decision-making. Values development, which involves knowing and defining personal values, also plays a crucial role in ethical decision-making. The strength of one's values can impact their commitment to ethical principles, with stronger values leading to more consistent ethical behavior. Additionally, factors such as locus of control, access to information, and personal power can affect an individual's ability to make ethical decisions. Religious beliefs often inform ethical principles and values, providing a moral compass and guiding individuals' decision-making processes. Different religious traditions offer unique perspectives on ethical decision-making, with principles such as compassion, honesty, justice, and love guiding individuals when faced with moral dilemmas. Understanding the impact of culture, personal experiences, and religion on morality and ethical decision-making is essential for promoting cross-cultural understanding and ethical decision-making in an increasingly interconnected world.
#
# --- 重新處理問題: question_19 ---
#   ✅ 回答: The Vietnam War was a complex and multifaceted conflict, driven by a combination of political, ideological, and strategic factors. The war was fueled by the Cold War rivalry between the US and the Soviet Union, as well as the fear of communist expansion in Southeast Asia. The political tensions leading up to the Vietnam War were characterized by a mix of strategic, ideological, and domestic political considerations. The US government's actions were shaped by a desire to contain the spread of communism and maintain its influence in the region. A pivotal event in the escalation of the war was the Gulf of Tonkin incident, which marked a significant increase in US involvement, including the passage of the Gulf of Tonkin Resolution and the deployment of ground combat troops. This incident has been the subject of controversy and debate, with some arguing it was a pretext for US intervention in the war.
#
# --- 重新處理問題: question_21 ---
# Error processing https://cybersecuritynews.com/weekly-cybersecurity-digest/: HTTPSConnectionPool(host='cybersecuritynews.com', port=443): Read timed out. (read timeout=5)
#   ✅ 回答: The recent increase in hacking activity can be attributed to a multifaceted interplay of factors, including the evolution of hacking methods and tools, significant shifts in online security measures, and various economic and social drivers. Recent trends in hacking have seen the adoption of advanced technologies such as Artificial Intelligence (AI), Machine Learning (ML), the Internet of Things (IoT), cloud computing, and blockchain. These technologies have introduced new vulnerabilities and opportunities for hackers to exploit, thereby contributing to the rise in hacking incidents. Furthermore, the changing landscape of online security, characterized by the use of AI-fueled threats and defense mechanisms, increased insider threats, escalating geopolitical tensions, and a surge in disruptive cyberattacks, zero-day vulnerabilities, and third-party risks, has created an environment conducive to hacking. Additionally, economic and social factors such as motivation, self-determination, and academic self-concept play a crucial role in driving individuals to engage in hacking activity. Understanding these factors, including the motivations and psyche of hackers, is essential for developing effective strategies to combat the increase in hacking activity. Therefore, addressing the surge in hacking requires a comprehensive approach that considers technological, security, and socio-economic aspects to mitigate vulnerabilities and deter potential hackers.
#
# --- 重新處理問題: question_22 ---
#   ✅ 回答: The U.S. Constitution has undergone significant changes throughout its history, with 27 amendments ratified since its adoption. The amendment process, outlined in Article V of the Constitution, has been used to refine governance, advance civil liberties, and address social injustices. Judicial interpretations, particularly by the Supreme Court, have played a crucial role in shaping the understanding and application of the Constitution, with landmark cases influencing civil rights, individual liberties, and the balance of power between the federal government and the states. Historical events and societal changes have prompted amendments and reinterpretations, showcasing the Constitution's capacity to adapt to changing times and respond to the needs of society. The interplay between these amendments, judicial interpretations, and historical context has made the Constitution a living document that continues to evolve and shape American law and society.
#
# --- 重新處理問題: question_24 ---
#   ✅ 回答: To prevent catalytic converter theft, police can employ a multi-faceted approach that involves law enforcement strategies, community engagement, and public awareness campaigns. First, identifying the common characteristics and locations of catalytic converter theft is crucial. This includes understanding that thieves often target vehicles with higher clearance and valuable converters, such as the Toyota Prius, Ford F-Series trucks, and SUVs like the Honda CR-V and Toyota 4Runner, and that they favor remote areas, residential driveways, and multi-vehicle parking lots for easier access and lower detection risk. With this knowledge, police can conduct targeted patrols and sting operations in high-risk areas. Additionally, police can work with vehicle owners to encourage the use of physical barriers, such as shields and cages, asset tagging with etching or high-heat paint, and onboard alarms. Furthermore, police can collaborate with regulatory bodies to enforce legislation requiring scrap dealers to document transactions, making it more difficult for thieves to sell stolen converters. Effective anti-theft devices, such as CatStrap, CatClamp, and Sparkwhiz, can also be promoted to vehicle owners as a means of protecting their property. Community engagement and awareness campaigns are vital in preventing catalytic converter theft. This can be achieved through public education on the risks and consequences of catalytic converter theft, encouraging community members to report suspicious activity, and implementing neighborhood watch programs. Police can also engage with the community by providing information on how to protect vehicles and offering free or low-cost anti-theft devices. By working together, law enforcement, vehicle owners, and the community can reduce the incidence of catalytic converter theft and create a safer environment for all.
#
# --- 重新處理問題: question_25 ---
# Error processing https://www.investopedia.com/financial-edge/0911/the-impact-of-september-11-on-business.aspx: HTTPSConnectionPool(host='www.investopedia.com', port=443): Read timed out. (read timeout=5)
# Error processing https://www.investopedia.com/financial-edge/0911/how-september-11-affected-the-u.s.-stock-market.aspx: HTTPSConnectionPool(host='www.investopedia.com', port=443): Read timed out. (read timeout=5)
#   ✅ 回答: The consequences of 9/11 were far-reaching and multifaceted, impacting global politics, economies, and international relations. The attacks led to a significant shift in global security measures, with the US launching the War on Terror, invading Afghanistan and Iraq, and implementing new security protocols. The economic consequences were substantial, including a decline in global stock markets, insurance losses of approximately $40 billion, and a rise in gold and oil prices. The impact on international relations was profound, with the emergence of new terrorist groups, the rise of anti-Americanism, and an ongoing debate about the balance between security, freedom, and human rights. The legacy of 9/11 continues to shape global politics, economies, and societies today, with ongoing challenges and complexities arising from the aftermath of the attacks.
#
# --- 重新處理問題: question_28 ---
#   💥 發生錯誤: 1 validation error for CriticalEvaluation
# critical_evaluation
#   Field required [type=missing, input_value={'tool_name': 'question_d...American situation."}]}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# --- 重新處理問題: question_31 ---
#   ✅ 回答: The FDIC's role encompasses aspects of relief, recovery, and reform. It provides relief by maintaining stability and public confidence in the banking system, facilitates recovery by preventing bank failures and protecting depositors, and implements reform through its adaptation to regulatory changes. Therefore, the FDIC's actions can be classified as a combination of relief, recovery, and reform.
#
# --- 重新處理問題: question_32 ---
#   💥 發生錯誤: 1 validation error for Summary
# summary
#   Field required [type=missing, input_value={'tool_name': 'search', '...ecurity on individuals'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# --- 重新處理問題: question_36 ---
#   💥 發生錯誤: 1 validation error for CriticalEvaluation
# critical_evaluation
#   Field required [type=missing, input_value={'tool_name': 'update', '...s financial health."}]}}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# --- 重新處理問題: question_38 ---
#   ✅ 回答: Mass shootings can be prevented through a combination of early intervention, mental health support, and effective gun control measures. Implementing policies such as licensing processes for gun purchasers, banning large-capacity magazines, and restricting access to assault weapons can also reduce the incidence of mass shootings. By addressing the root causes of violence at individual, institutional, and societal levels, and through a holistic approach to safety, it is possible to prevent mass shootings and reduce gun violence.
#
# --- 重新處理問題: question_39 ---
#   ✅ 回答: The militarization of police in the United States is a complex and multifaceted issue that has evolved over several decades. Key historical events, such as the civil rights movement and urban riots of the 1960s, have significantly contributed to this trend by prompting the adoption of military tactics and equipment. The War on Drugs, which began in the 1970s and intensified in the 1980s, further accelerated the militarization process by providing a rationale for the use of military-grade equipment and tactics in domestic law enforcement. The 1033 program, established in 1990, has played a crucial role in facilitating the transfer of surplus military equipment to police departments, raising concerns about the erosion of civil liberties and the potential for excessive force. The legacy of these events continues to shape police practices and community relations, with ongoing debates about the necessity of militarized policing, its impact on public trust, and the need for reform. In summary, the militarization of police in the United States is a gradual process that has been influenced by a combination of historical events, legislative changes, and policy decisions, with significant milestones including the civil rights movement, the War on Drugs, and the implementation of the 1033 program.
#
# --- 重新處理問題: question_40 ---
#   ✅ 回答: The electronic environment significantly impacts personal security, introducing various risks such as data breaches, account hijacking, insecure APIs, insider threats, denial-of-service attacks, data loss, lack of cloud visibility, shared responsibility model, compliance violations, advanced persistent threats, lack of encryption, poor identity and access management, shadow IT, third-party risk, container vulnerabilities, and supply chain attacks. Despite these risks, individuals can protect themselves by being aware of online security risks and taking steps to mitigate them. Key protection strategies include using strong, unique passwords; enabling two-factor authentication; keeping software and operating systems up to date; being cautious when using public Wi-Fi; and monitoring online accounts for suspicious activity. Additionally, utilizing a virtual private network (VPN), encrypting sensitive data, and using secure communication tools can help protect against various types of cyber threats. It is also crucial to be mindful of online privacy settings and to use reputable antivirus software and a firewall to prevent malware and other types of cyber attacks. By understanding these risks and adopting proactive protection strategies, individuals can substantially mitigate the risks posed by the electronic environment and ensure their personal security.
#
# --- 重新處理問題: question_43 ---
# Error processing https://www.thoughtco.com/congressional-oversight-4177013: HTTPSConnectionPool(host='www.thoughtco.com', port=443): Read timed out. (read timeout=5)
#   ✅ 回答: The issue of distributing power between branches is complex and multifaceted, requiring consideration of historical, constitutional, and practical factors. To more evenly distribute power between the branches, several mechanisms could be implemented. Firstly, strengthening congressional oversight of the executive branch can be achieved through various means, including congressional hearings, investigations, the power of the purse, and confirmation of presidential appointments. Technological advancements can also enhance oversight, providing new tools and methods for monitoring and holding the executive branch accountable. However, it's crucial to consider the potential consequences of these actions, including increased political polarization and constitutional challenges. The judicial branch has played a significant role in shaping the balance of power between the branches through its interpretations of laws and the Constitution, particularly in cases involving enforcement lawmaking. Therefore, a balanced approach that promotes transparency, accountability, and cooperation between branches is necessary to achieve a more even distribution of power. This could involve reforms such as increasing congressional oversight capabilities, leveraging technological advancements for more effective monitoring, and fostering a collaborative environment between the branches to ensure that each branch respects the boundaries and authority of the others. Ultimately, the goal should be to strike a balance that protects individual rights, prevents tyranny, and ensures the effective functioning of the government.
#
# --- 重新處理問題: question_48 ---
#   💥 發生錯誤: 1 validation error for Summary
# summary
#   Field required [type=missing, input_value={'tool_name': 'search', '...mental health outcomes'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# --- 重新處理問題: question_50 ---
#   ✅ 回答: Miners during the gold rush faced numerous dangers that threatened their lives, health, and well-being. Environmental hazards such as deforestation, landslides, floods, and wildfires posed significant threats. Deforestation led to soil erosion, and the removal of trees disrupted wildlife habitats. The pursuit of gold involved extensive excavation, which altered the physical landscape and led to habitat loss for aquatic species. Additionally, the gold rush resulted in water pollution from sedimentation, turbidity, and mercury contamination, affecting aquatic life and ecosystems.
#
# Miners also faced various health risks, including respiratory diseases, injuries, and waterborne illnesses. Exposure to mercury was a significant health risk, and miners were also prone to silicosis, tuberculosis, and other lung diseases due to inhaling silica particles. The lack of proper sanitation and hygiene led to the spread of diseases such as cholera, dysentery, and typhoid fever.
#
# Furthermore, the gold rush had a devastating impact on Native American tribes, leading to displacement, disease, violence, and cultural disruption. The influx of settlers brought diseases such as smallpox, measles, and cholera, which decimated Native American populations. Violence and conflict arose as settlers encroached on Native American lands, leading to massacres and forced relocation. The gold rush disrupted traditional Native American ways of life, including their economies, social structures, and cultural practices. The legacy of the gold rush continues to affect Native American communities today, with ongoing struggles for land rights, self-determination, and cultural preservation.
#
# In conclusion, the dangers faced by miners during the gold rush were multifaceted and far-reaching, encompassing environmental, health, and social risks. The pursuit of gold had significant consequences for the miners themselves, as well as for the Native American tribes and the environment.
#
# --- 重新處理問題: question_52 ---
# Error processing https://api.pageplace.de/preview/DT0400.9781000771282_A43369302/preview-9781000771282_A43369302.pdf: HTTPSConnectionPool(host='api.pageplace.de', port=443): Max retries exceeded with url: /preview/DT0400.9781000771282_A43369302/preview-9781000771282_A43369302.pdf (Caused by NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f9f555eae10>: Failed to establish a new connection: [Errno 101] Network is unreachable'))
#   ✅ 回答: Genres are effective in characterizing media messages because they provide a shared framework for categorization and shaping audience expectations. This framework enables the recognition of patterns and conventions within specific categories, such as themes, styles, formats, or narratives, allowing creators to effectively tell stories and create a visual shorthand that resonates with the audience. Furthermore, genres create a space for innovation, where creators can push the limits of genre, blending elements or twisting conventions to surprise and engage their audience. The effectiveness of genres is deeply rooted in the interplay between genre conventions and audience expectations, making them a vital tool in the media industry.
#
# --- 重新處理問題: question_54 ---
#   ✅ 回答: The importance of all people knowing how to read and write critically cannot be overstated. Critical reading and writing skills empower individuals with the ability to navigate and understand complex information, evaluate arguments, identify biases, and make informed decisions. This, in turn, contributes to personal growth, as individuals expand their knowledge and understanding, develop critical thinking and analytical skills, and cultivate empathy and self-awareness. Moreover, critical literacy has a profound impact on societal development and progress, as it enables individuals to question dominant narratives, challenge inequalities, and promote social justice. By fostering a more engaged, critically thinking, and empathetic citizenry, critical reading and writing skills are essential for addressing complex challenges, promoting a more just and equitable society, and ultimately, creating a better world for all.
#
# --- 重新處理問題: question_56 ---
# Error processing https://www.thoughtco.com/what-a-0-percent-unemployment-means-1147540: HTTPSConnectionPool(host='www.thoughtco.com', port=443): Read timed out. (read timeout=5)
# Error processing https://www.investopedia.com/insights/downside-low-unemployment/: HTTPSConnectionPool(host='www.investopedia.com', port=443): Read timed out. (read timeout=5)
# Error processing https://www.thoughtco.com/what-a-0-percent-unemployment-means-1147540: HTTPSConnectionPool(host='www.thoughtco.com', port=443): Read timed out. (read timeout=5)
#   ✅ 回答: Zero unemployment is not necessarily a good thing due to potential drawbacks such as difficulties in recruitment and retention, lost productivity, and the possibility of another recession. However, it can also have benefits such as increased productivity, reduced social and economic costs associated with unemployment, and economic growth. A healthy unemployment rate between 3% and 5% is considered optimal as it balances the benefits and drawbacks, allowing for job turnover, job searching, and mobility in the labor market while indicating a relatively strong economy.
#
# --- 重新處理問題: question_61 ---
#   ✅ 回答: Discrimination in the workplace is a complex and multifaceted issue that can take many forms, including age, disability, gender, national origin, pregnancy, race, color, religion, and sex. Understanding and addressing these forms is crucial for promoting equality and fairness. The various forms of discrimination can be addressed through policies, training, and fostering an inclusive work environment. This includes preventing harassment, retaliation, and unfair treatment. Measuring and identifying discrimination in the workplace can be achieved through surveys, statistical analysis, and observational studies. These methods help assess the existence and extent of discrimination. To prevent workplace discrimination, employers can implement strong anti-discrimination policies, provide training and awareness programs, and establish clear reporting procedures for incidents of harassment or discrimination. Employers must also comply with anti-discrimination laws, such as Title VII of the Civil Rights Act, and ensure protection against retaliation for employees who report discrimination or harassment. Furthermore, the results of discrimination measurements can be used to inform changes by employing metrics to benchmark and track diversity, equity, and inclusion (DEI) progress, such as measuring inclusion in the workplace and using DEI metrics to ensure a merit-based culture. In conclusion, discrimination in the workplace is a significant issue that requires a comprehensive approach to address. By understanding the forms of discrimination, implementing effective policies and training, and using metrics to track progress, employers can create a more inclusive and equitable work environment for all employees.
#
# --- 重新處理問題: question_62 ---
# Error processing https://www.sas.upenn.edu/~jtreat/rs/002/Judaism/holocaust.html: HTTPSConnectionPool(host='www.sas.upenn.edu', port=443): Max retries exceeded with url: /~jtreat/rs/002/Judaism/holocaust.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
# Error processing https://www.yadvashem.org/remembrance/archive/central-theme/lost-world.html: HTTPSConnectionPool(host='www.yadvashem.org', port=443): Max retries exceeded with url: /remembrance/archive/central-theme/lost-world.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
# Error processing https://www.yadvashem.org/remembrance/archive/central-theme/lost-world.html: HTTPSConnectionPool(host='www.yadvashem.org', port=443): Max retries exceeded with url: /remembrance/archive/central-theme/lost-world.html (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
#   💥 發生錯誤: 1 validation error for Summary
# summary
#   Field required [type=missing, input_value={'tool_name': 'search', '...onses to the Holocaust'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# --- 重新處理問題: question_65 ---
#   ✅ 回答: The Australian Gold Rush had a profound impact on the country's history, transforming it from a struggling colony to a prosperous nation. It led to significant population growth, demographic changes, and economic development, shaping Australia's identity and contributing to its modern society and economy.
#
# --- 重新處理問題: question_70 ---
# Error processing https://wams.nyhistory.org/a-nation-divided/antebellum/sojourner-truth/: HTTPSConnectionPool(host='wams.nyhistory.org', port=443): Max retries exceeded with url: /a-nation-divided/antebellum/sojourner-truth/ (Caused by SSLError(SSLCertVerificationError(1, '[SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1006)')))
#   ✅ 回答: Sojourner Truth escaped slavery in 1827 by running away from her owner, John Dumont, and finding refuge with the Van Wagenen family, who later bought her freedom for $20. Born into slavery in 1797 in New York, Sojourner Truth was sold multiple times and experienced harsh physical labor and violent punishments. Her life as a slave was marked by suffering and hardship, but she found the strength to escape and later became a prominent abolitionist, women's rights activist, and preacher. Although the Underground Railroad was a network of secret routes and safe houses used by enslaved African Americans to escape slavery during the 19th century, there is no evidence that Sojourner Truth used it to escape. Instead, she found freedom through the assistance of the Van Wagenen family, who bought her freedom and allowed her to begin her journey as a vocal advocate for the rights of women and African Americans.
#
# --- 重新處理問題: question_71 ---
# Error processing https://www.newsmax.com/finance/georgementz/college-football-revenue/2024/10/16/id/1184285/: HTTPSConnectionPool(host='www.newsmax.com', port=443): Read timed out. (read timeout=5)
#   ✅ 回答: The college football playoff should expand, as the benefits of increased excitement and competition, a more level playing field for teams from all divisions, and significant financial benefits outweigh the drawbacks. A well-designed expansion, potentially to a 12-team format, could generate substantial revenue, promote competitive balance, and create a more thrilling postseason experience for fans.
#
# --- 重新處理問題: question_72 ---
#   ✅ 回答: Nurses are paid highly due to a combination of factors, including their level of education, experience, certification, shift, and location. Higher nursing degrees, such as master's degrees, and specialized certifications can significantly increase a nurse's salary. For instance, nurse practitioners and certified registered nurse anesthetists can earn average salaries of $95,000 and $133,000, respectively. Experience also plays a crucial role, with nurses having 20 years or more of experience earning substantially more than those with less than one year. The cost of living in certain locations, particularly cities with high costs of living, often necessitates higher base salaries to compensate. Certain specialties, such as critical care and pediatrics, can also lead to higher salaries.
# Global comparisons reveal that nurse salaries vary significantly across different countries and regions. The highest-paying countries for nurses include Switzerland, Luxembourg, and the United States, with average annual salaries ranging from $74,710 to $94,869. Other high-paying countries for nurses include Denmark, Australia, and Canada, with average annual salaries ranging from $55,850 to $64,705. The cost of living, demand for nurses, and local economic conditions are key factors that influence nurse salaries in different countries.
# In conclusion, the high salaries of nurses can be attributed to the demand for skilled professionals, the cost of living in certain locations, and the economic conditions of different countries and regions.
#
# --- 重新處理問題: question_73 ---
#   ✅ 回答: Social injustice has a profound impact on individuals and society, affecting mental health and economic stability. The various forms of social injustice, including employment discrimination, educational inequality, police brutality, and systemic discrimination, can lead to mental health issues such as depression and anxiety. Additionally, social injustice can result in economic disparities, including increased income inequality and reduced economic mobility. Understanding the long-term effects of social injustice on mental health is crucial for informing treatment and support strategies, and designing economic policies to reduce social injustice is essential for promoting economic equality and stability. By addressing the complex and multifaceted nature of social injustice, we can work towards creating a more just and equitable society.
#
# --- 重新處理問題: question_76 ---
# Error processing https://www.reddit.com/r/gpumining/comments/7lz7od/hardware_failure_rates_reliability_downtime_and/: HTTPSConnectionPool(host='www.reddit.com', port=443): Read timed out. (read timeout=5)
# Error processing https://emcd.io/articles/mining/how-long-does-a-gpu-last-while-mining/: HTTPSConnectionPool(host='emcd.io', port=443): Max retries exceeded with url: /articles/mining/how-long-does-a-gpu-last-while-mining/ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7f9f55a0b450>: Failed to resolve 'emcd.io' ([Errno -3] Temporary failure in name resolution)"))
# Error processing https://www.nicehash.com/blog/post/can-mining-damage-my-gpu-or-a-pc: HTTPSConnectionPool(host='www.nicehash.com', port=443): Max retries exceeded with url: /blog/post/can-mining-damage-my-gpu-or-a-pc (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7f9f48438a50>: Failed to resolve 'www.nicehash.com' ([Errno -3] Temporary failure in name resolution)"))
# Error processing https://emcd.io/articles/mining/how-long-does-a-gpu-last-while-mining/: HTTPSConnectionPool(host='emcd.io', port=443): Max retries exceeded with url: /articles/mining/how-long-does-a-gpu-last-while-mining/ (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x7f9f484b2c10>: Failed to resolve 'emcd.io' ([Errno -3] Temporary failure in name resolution)"))
#   ✅ 回答: Mining can potentially hurt GPUs due to the high stress it places on the hardware, particularly in terms of heat generation and electrical stress. This stress can lead to physical wear and tear on GPU components, such as capacitors and VRAM, which are prone to degradation due to high temperatures. The extent of the damage depends on various factors, including the specific GPU model, operating conditions, and maintenance practices.
#
# Cryptocurrency mining can negatively impact GPU performance and lifespan due to increased heat generation, electrical stress, and wear and tear. Proper cooling techniques, such as using high-quality fans or liquid cooling systems, and regular maintenance, like cleaning the GPU and monitoring temperature, are essential to mitigate these effects. Overclocking can also reduce GPU lifespan, and miners should find a balance between performance and longevity.
#
# Understanding the signs of GPU degradation, such as increased temperature, decreased performance, and artifacting, can help miners take proactive steps to extend the life of their GPUs. The expected lifespan of a GPU used for mining varies, but it can range from 2 to 5 years, depending on usage and maintenance.
#
# In conclusion, mining can potentially hurt GPUs if not properly managed. However, by taking proactive steps to mitigate the effects of heat generation, electrical stress, and wear and tear, miners can help extend the life of their GPUs and ensure optimal performance.
#
# --- 重新處理問題: question_77 ---
# Error processing https://www.verywellmind.com/what-is-motivation-2795378: HTTPSConnectionPool(host='www.verywellmind.com', port=443): Read timed out. (read timeout=5)
# Error processing https://helpfulprofessor.com/types-of-motivation/: ('Received response with content-encoding: gzip, but failed to decode it.', error('Error -3 while decompressing data: incorrect header check'))
#   ✅ 回答: The relationship between motivation and perception is complex and multifaceted. Through intrinsic and extrinsic motivation, individuals' perceptions of themselves, their abilities, and their place within social and educational contexts are significantly influenced. Intrinsic motivation, driven by internal desires and impulses, fosters a positive and inclusive perception, particularly in educational settings like STEM. On the other hand, extrinsic motivation, influenced by external factors such as rewards and social recognition, also impacts perception by providing tangible goals and satisfaction. The interaction between these two types of motivation is crucial, as it influences task satisfaction and behavior. Understanding the different types of motivation, including positive, negative, personal, and social motivations, and their effects on perception is essential for creating environments that support autonomy, competence, and relatedness. By recognizing the role of motivation in shaping perception, individuals and educators can work to promote intrinsic motivation, provide appropriate extrinsic motivators, and foster a growth mindset, ultimately leading to enhanced performance, creativity, and well-being.
#
# --- 重新處理問題: question_83 ---
#   ✅ 回答: The evolution of photography art as a result of cinema is a multifaceted phenomenon that encompasses both technological advancements and the adoption of cinematic techniques. Cinema's influence on photography can be traced back to the early days of film, where the introduction of synchronized sound, color films, and digital filmmaking expanded the possibilities of visual storytelling and redefined what was possible on screen. Photographers, inspired by the cinematic medium, began to experiment with new techniques to create more dynamic and engaging images. The use of lighting, composition, and color grading became crucial elements in photography, allowing artists to tell stories and evoke emotions in their audience. The cinematic look, characterized by the use of wide apertures, experimentation with different lighting setups, and post-processing techniques such as color grading and contrast adjustment, has become a distinctive style in photography. Furthermore, the development of cinematic filters and presets has enabled photographers to give their images a film-like quality, blurring the lines between photography and cinema. The convergence of these two art forms has led to the development of new styles and genres, pushing the boundaries of what is possible in photography. Ultimately, the influence of cinema on photography art has been profound, transforming the medium and enabling photographers to create complex, visually stunning, and emotionally resonant images that captivate and inspire audiences.
#
# --- 重新處理問題: question_87 ---
# Error processing https://www.battlefields.org/learn/articles/radical-republicans: HTTPSConnectionPool(host='www.battlefields.org', port=443): Read timed out. (read timeout=5)
#   ✅ 回答: The Radical Republicans disapproved of Presidential Reconstruction due to its leniency towards former Confederates and lack of protections for freedmen. The main goals of Radical Republicans during the Reconstruction era were to achieve the immediate, complete, and permanent eradication of slavery in the United States, guarantee civil rights for freedmen, and ensure equal treatment and enfranchisement of African Americans. However, Presidential Reconstruction under Andrew Johnson did not meet these goals. Johnson's plan required southern states to uphold the abolition of slavery, swear loyalty to the Union, and pay off war debt, but it also allowed southern states to establish their own governments with minimal federal oversight and granted pardons to former Confederates. This leniency towards former Confederates and lack of protections for freedmen led to the Radical Republicans' disapproval of Presidential Reconstruction. They sought to protect the rights of formerly enslaved individuals and limit the power of former Confederates, which were not achieved through Johnson's plan.
#
# --- 重新處理問題: question_89 ---
#   ✅ 回答: Homophobia has a profound and far-reaching impact on mental health, affecting individuals and communities in complex and interconnected ways. The common manifestations of homophobia, including institutional, internalized, and interpersonal forms, can exacerbate each other and lead to a wide range of negative effects on mental health. Societal homophobia, in particular, can lead to increased stress, anxiety, depression, and suicidality among LGBTQ+ individuals, highlighting the need for inclusive policies, education, and community support to promote positive mental health outcomes. However, the presence of strong support systems, including family, friends, and community, can provide a safe and nurturing environment, helping to counteract the negative effects of homophobia and promoting resilience and well-being. To mitigate the effects of homophobia on mental health, it is essential to address these issues at multiple levels, from policy and societal attitudes to individual support, and to work towards creating a more inclusive and accepting society.
#
# --- 重新處理問題: question_91 ---
# Error processing https://www.focusongod.com/Luke-05.htm: ('Connection aborted.', ConnectionResetError(104, 'Connection reset by peer'))
#   ✅ 回答: The opposition Jesus faced from his enemies provides valuable lessons for believers today.
#    By understanding the nature of the opposition, including the challenges from the Pharisees, Sadducees, scribes, Herodians, and chief priests,
#    and Jesus' responses to them, believers can learn to respond to their own enemies with love, forgiveness, and compassion.
#    Additionally, recognizing the motivations behind the opposition, such as the desire to maintain power and influence,
#    can help believers to rise above their natural instincts and emotions and to extend grace to those who wrong them.
#    The lessons that can be learned from the opposition Jesus faced from his enemies include:
#    1. Responding to enemies with love, forgiveness, and compassion:
#    Jesus' example and teachings challenge his followers to rise above their natural instincts and emotions and to respond to opposition with faith, forgiveness, and love.
#    2. Rising above natural instincts and emotions:
#    Jesus taught his followers to love their enemies, pray for those who persecute them, and extend grace to those who wrong them.
#    3. Understanding the motivations behind opposition:
#    The opposition Jesus faced was rooted in religious, political, and social concerns,
#    and identifying these motivations can help in understanding the depth of opposition and the lessons that can be learned.
#    By applying these lessons, believers can grow in their faith, develop a deeper understanding of God's love and forgiveness,
#    and learn to respond to opposition in a way that honors God.
#
# --- 重新處理問題: question_92 ---
# ...
#
# --- 重新處理問題: question_206 ---
# Error processing https://stillmed.olympic.org/media/Document+Library/OlympicOrg/IOC/What-We-Do/Protecting-Clean-Athletes/Athletes-Space/Athletes-Entourage/Coaches/EN-Qualities-of-a-coach.pdf: HTTPSConnectionPool(host='stillmed.olympic.org', port=443): Read timed out. (read timeout=5)
# Error processing https://ebrary.net/146156/education/effective_coaching: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response'))
#   ✅ 回答: Coaches have a profound impact on players through their coaching qualities and strategies, influencing player development, performance, and overall well-being. The key qualities that make a coach effective include being a role model, knowledgeable, honest, and a strong communicator, with a positive vision and trust in their team. Coaches influence player development and performance by building strong relationships, setting clear and achievable goals, providing individualized support, and adopting autonomy-supportive coaching styles. These styles, which provide freedom and support, are most effective in fulfilling athletes' psychological needs and resulting in greater success and improvement. By adopting efficient coaching styles and considering the unique needs and goals of their athletes, coaches can have a lasting and positive influence on their players' lives and athletic careers.
#
# --- 重新處理問題: question_212 ---
#   💥 發生錯誤: 1 validation error for Summary
# summary
#   Field required [type=missing, input_value={'tool_name': 'search', '...ractions across scales'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# --- 重新處理問題: question_216 ---
#   ✅ 回答: Improving energy security requires a comprehensive approach that addresses current challenges, expands renewable energy sources, and enhances energy efficiency. The current challenges to energy security, including reliance on imported fuels, aging infrastructure, and extreme weather events, are being addressed through diversification of energy sources, expansion of renewables, and modernization of grids, focusing on decentralized systems, microgrids, and resilient technologies to ensure stable, affordable, and uninterrupted energy supply. Renewable energy sources, such as wind and solar power, are being integrated into the energy mix to reduce dependence on imported fuels and mitigate price volatility, leading to a more stable and resilient energy system. Energy efficiency is being improved through the use of energy-efficient appliances, smart thermostats, LED lighting, and advanced insulation materials, as well as techniques such as airflow management, behavior modification, and the integration of renewable energy sources, resulting in significant reductions in energy consumption and costs. Overall, this multifaceted approach can reduce price volatility, decrease dependence on imported fuels, and make the energy system more stable and resilient, ultimately improving energy security.
#
# --- 重新處理問題: question_334 ---
# Error processing https://www.investopedia.com/financial-edge/1211/how-taxes-affect-the-economy.aspx: HTTPSConnectionPool(host='www.investopedia.com', port=443): Read timed out. (read timeout=5)
#   ✅ 回答: Changing tax rates have a profound impact on the timing strategy, influencing investment, spending, and work behaviors. The current US tax rates, ranging from 10% to 37%, play a significant role in shaping financial decisions. Tax brackets, deductions such as the Earned Income Tax Credit (EITC), and credits contribute to the overall tax liability and financial planning. Furthermore, changes in tax rates can stimulate economic growth by increasing after-tax returns on investments, thus affecting decisions on work, savings, and investments. The impact of tax rate changes varies based on the type of tax, tax rate, and investment vehicle. Therefore, understanding the intricacies of tax rates and their effects on financial planning is essential for making informed decisions regarding timing strategy.
#
# --- 重新處理問題: question_336 ---
#   ✅ 回答: The innovation of the inventor, specifically the improvement of the steam engine, had a profound impact on society. This innovation was crucial for the Industrial Revolution, marking a significant shift from manual labor to machine-based manufacturing and thereby altering the economic landscape. The primary societal areas affected by this innovation include industrial production, transportation networks, and daily life conveniences. Notable changes resulting from this innovation include widespread urbanization, a redistribution of the workforce, and an overall improvement in the quality of life. The steam engine's enhancement facilitated increased efficiency and power, leading to advancements in various sectors such as manufacturing and transportation. In conclusion, the inventor's innovation played a pivotal role in transforming industries and daily life, leaving a lasting legacy on the world.
#
# --- 重新處理問題: question_382 ---
#   💥 發生錯誤: 1 validation error for Summary
# summary
#   Field required [type=missing, input_value={'tool_name': 'search', '...mental health research'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# --- 重新處理問題: question_390 ---
# Error processing https://www.investopedia.com/terms/e/economic-collapse.asp: HTTPSConnectionPool(host='www.investopedia.com', port=443): Read timed out. (read timeout=5)
#   ✅ 回答: Economic collapse is a complex and multifaceted phenomenon that can have severe and far-reaching consequences for individuals, communities, and the global economy. It is often triggered by a combination of internal and external factors, including poor economic policies, global economic trends, and geopolitical events. The causes of economic collapse can be broadly categorized into internal factors, such as hyperinflation, debt crises, and trade deficits, and external factors, such as global economic downturns, wars, and natural disasters.
#
# The impact of an economic collapse on individuals and communities can vary widely, with potential effects including job loss, reduced access to essential services, increased poverty, and social unrest. Social safety nets and community support structures play a vital role in mitigating these effects and helping individuals and communities recover from economic crises.
#
# On a global scale, an economic collapse can lead to widespread instability, increased poverty, and significant environmental degradation. The interconnectedness of global economies and systems means that an economic crisis in one country or region can have far-reaching consequences for other countries and the global economy as a whole. International cooperation and proactive economic policies are essential for preventing or managing such crises and promoting global economic stability and growth.
#
# In conclusion, economic collapse is a serious and complex phenomenon that requires a comprehensive and multifaceted approach to understand and address. By understanding the causes and implications of economic collapse, we can work towards preventing or mitigating potential economic crises and promoting global economic stability and growth.
#
# --- 重新處理問題: question_393 ---
#   ✅ 回答: Yes, there are degrees of sociopathy. Sociopathic traits can vary in severity or intensity, existing on a spectrum. This spectrum includes characteristics such as a lack of empathy, manipulative behavior, impulsivity, and superficial charm, with traits ranging from mild to severe. Standardized assessments like the DSM-5 and the Hare Psychopathy Checklist-Revised can help measure the severity of sociopathic tendencies by evaluating criteria such as lack of empathy, impulsivity, and manipulative behavior. Understanding this spectrum is essential for navigating relationships and for professionals to develop effective treatment plans. The concept of degrees of sociopathy challenges the traditional view of sociopathy as a fixed condition and recognizes that individuals can exhibit different levels of sociopathic traits.
#
# --- 重新處理問題: question_410 ---
#   ✅ 回答: Eugenics is considered unethical primarily because of its historical implementation in discriminatory policies and practices, its foundational relationship with genetic determinism, and its role in justifying social inequality. The concept of eugenics, which aims to improve the human species through selective breeding and genetic manipulation, has been controversial since its inception due to its potential for misuse and its inherent biases. Historically, eugenics has been used to justify forced sterilizations, racial segregation, and other forms of discrimination, leading to severe human rights violations. The most notorious example of eugenics' dark past is its association with the Holocaust, where the idea of creating a 'master race' through genetic purification was used to justify the systematic persecution and genocide of millions of people. Furthermore, eugenics perpetuates genetic determinism, the idea that social behaviors and classes are genetically predetermined, which has been used to justify social inequality and discrimination against certain groups perceived as 'genetically inferior.' Despite its evolution into modern genetic engineering, eugenics retains ethical concerns regarding its potential for discrimination and the manipulation of human genes. Given its troubled history, eugenics is widely regarded as unethical due to its association with discriminatory ideologies, its role in justifying atrocities, and its inherent potential for misuse in modern genetics.
#
# --- 重新處理問題: question_417 ---
#   💥 發生錯誤: 1 validation error for Summary
# summary
#   Field required [type=missing, input_value={'tool_name': 'search', '...atient confidentiality'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# --- 重新處理問題: question_466 ---
# Error processing https://www.verywellmind.com/what-is-a-projection-defense-mechanism-5194898: HTTPSConnectionPool(host='www.verywellmind.com', port=443): Read timed out. (read timeout=5)
#   ✅ 回答: People project their insecurities as a complex psychological mechanism to protect their ego and maintain a favorable self-image. This behavior stems from various sources of insecurity, including societal pressures, personal experiences, and internal doubts, which can lead to feelings of inadequacy and low self-esteem. Common sources of insecurity in individuals, such as body image issues, fear of failure, and social insecurity, play a significant role in why people project their insecurities. The psychological concept of projection is closely linked to self-perception and defense mechanisms, serving as a way for individuals to attribute their unacceptable thoughts, feelings, or impulses to others, thereby shielding their ego from anxiety-provoking thoughts or feelings and avoiding internal conflict. By understanding the roots of insecurity and the psychological concept of projection, it becomes clear that people project their insecurities as a defense mechanism to avoid acknowledging and dealing with their own internal doubts and fears. This insight offers a comprehensive explanation for the original question, highlighting the intricate relationship between insecurity, self-perception, and the psychological need to project insecurities onto others.
#
# --- 重新處理問題: question_475 ---
#   ✅ 回答: The question of whether police want gun control is complex and multifaceted, reflecting a wide range of views within law enforcement. Police unions, which often represent the collective interests of law enforcement officers, have evolved in their stance on gun control over time. Some police unions now support more restrictive gun laws, including bans on assault-style rifles and high-capacity magazines, in an effort to reduce gun violence. However, not all police unions agree on this stance, and there is considerable variation in the views of individual police officers. Many officers believe that armed citizens can help prevent large-scale shootings and oppose stricter gun laws, while there is broad support among both police and the public for certain reforms such as background checks and preventing the mentally ill from purchasing guns. Ultimately, the diversity of opinions within law enforcement underscores the challenge of finding a unified position on gun control, but areas of agreement, such as support for background checks and restrictions on access for the mentally ill, highlight potential avenues for policy reform that could garner widespread support.
#
# --- 重新處理問題: question_163 ---
#   💥 發生錯誤: 1 validation error for Summary
# summary
#   Field required [type=missing, input_value={'tool_name': 'search', '...n reducing self-stigma'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# --- 重新處理問題: question_66 ---
# Error processing https://nursing-science.com/knowledgebase/how-are-nursing-standards-developed: HTTPSConnectionPool(host='nursing-science.com', port=443): Read timed out. (read timeout=5)
#   ✅ 回答: Nursing standards are developed through a collaborative process involving several organizations.
#    The American Nurses Association (ANA) plays a crucial role in defining the scope and standards of nursing practice,
#    ensuring they are evidence-based and reflect current best practices.
#    Other organizations involved in developing nursing standards include the American Nurses Credentialing Center (ANCC),
#    National League for Nursing (NLN), Accreditation Commission for Education in Nursing (ACEN),
#    Commission on Collegiate Nursing Education (CCNE), and National Student Nurses’ Association (NSNA).
#    The process for creating and updating nursing standards involves several steps,
#    including the development of general nursing scope and standards by the ANA and the creation of specialty-specific standards by organizations
#    such as the Association for Nursing Professional Development.
#    The revision process includes the formation of a work group, the review of foundational documents,
#    and the incorporation of new roles and competencies.
#    The standards of professional practice are divided into two categories:
#    standards of practice, which define what nursing professional development (NPD) practitioners do,
#    and standards of professional performance, which describe how NPD practitioners comply with the standards of practice and perform their roles.
#    The revised standards include new competencies, such as the integration of cultural competency statements and the addition of a standard on change management.
#
# --- 重新處理問題: question_125 ---
#   💥 發生錯誤: 1 validation error for Summary
# summary
#   Field required [type=missing, input_value={'tool_name': 'search', '...n-American communities'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.10/v/missing
#
# ✅ 重新處理指定問題已完成。結果已更新至 llama_experiment_results_makeup_exam2.jsonl

# %%
import json
from dotenv import load_dotenv

load_dotenv()

eval_prompt_p1 = """You are asked to assess the quality of an AI assistant's answer to a user's question as an impartial judge. Since the type of answer you are evaluating is [Solve Professional Problem], you need to evaluate the answer in the following 5 criteria:
1. Factuality: Whether the information provided is accurate and based on reliable facts and data.
2. User Satisfaction: Whether the response meets the user's question and needs and provides a comprehensive and appropriate answer to the question.
3. Clarity: Whether the response is clear and understandable, and whether it uses concise language and structure so that the user can easily understand it.
4. Logical Coherence: Whether the response maintains overall consistency and logical coherence between different sections, avoiding self-contradiction.
5. Completeness: Whether the response provides sufficient information and details to meet the user's needs, and whether it avoids omitting important aspects.
6. Note that a longer answer is not always better, the answer that is concise and meets the above requirements is the best.

We will provide you with the user's question, an 8-score reference answer, and answers from the AI assistant that needs your assessment. When starting your evaluation, you need to follow the reasoning steps below:
1. Compare the AI assistant's answer with the reference answer, point out any shortcomings in the AI assistant's answer, and explain further.
2. Evaluate the AI assistant's answer in terms of the different criteria, giving each criterion a score from 1 to 10 after the evaluation of each.
3. Finally, combine the evaluations from each criterion and give the AI assistant's answer a composite score of 1 to 10.
4. Your scoring needs to be as rigorous as possible and adhere to the following scoring rules: in general, the higher the quality of the model's answers, the higher the score.
The two most important criteria are factual correctness and fulfillment of user needs, and the scores for these two dimensions dominate the final composite score.

When the model answer has irrelevance to the question, or intrinsically factually incorrect, or generates harmful content, the total score should be 1 to 2;
When the model answer has no serious errors and is largely harmless, but is of low quality and does not meet user requirements, the total score must be 3 to 4;
When the model answer basically meets the user's needs but performs poorly on some criteria and is of medium quality, the total score can be 5 to 6;
When the quality of the model response is similar to the reference answer and performs well in all criteria, the total score should be 7 to 8;
A score of 9 to 10 can only be achieved if the model significantly exceeds the quality of the reference answer, adequately addresses the user's question and all the needs, and is close to a perfect score on all criteria. As an example, the reference answer would receive a score of 8.

You need to evaluate and explain before you score. Your explanation of each criterion needs to be followed by the scoring. After that, at the end of your answer, return all of your scores in the following dictionary format, including the curly brackets, and make sure that your scores are integers:
{'Dimension 1': scoring, 'Dimension 2': scoring, ... , 'Final Score': Score}, e.g. {'Factuality': 9, 'User Satisfaction': 6, ... , 'Final Score': 7}.
"""


def compare_answers(filename="experiment_results.jsonl"):
    """
    開啟 JSONL 檔案，針對相同的 question_id，比較不同系統的答案，並回傳問題內容。
    "MindSearch" (gpt-4o) 的答案被視為參考答案，
    "ReAct" (gpt-4o) 和 "CQ_Solver" (gpt-4o) 的答案將與之比較。

    Args:
        filename (str): JSONL 檔案的名稱。

    Returns:
        dict: 一個字典，key 是 question_id，value 是一個包含問題、參考答案和要比較答案的字典。
              例如:
              {
                  "question_498": {
                      "question": "how does case management improve patient outcomes",
                      "reference_answer": "Case management...",
                      "ReAct_answer": "...",
                      "CQ_Solver_answer": "..."
                  },
                  "question_499": {
                      "question": "...",
                      "reference_answer": "...",
                      "ReAct_answer": "...",
                      "CQ_Solver_answer": "..."
                  },
                  ...
              }
    """
    results = {}
    data_by_question_id = {}

    with open(filename, 'r') as f:
        for line in f:
            try:
                record = json.loads(line.strip())
                question_id = record.get("question_id")
                question = record.get("question")
                system = record.get("system")
                model = record.get("model")
                answer = record.get("answer")

                if question_id and model == "gpt-4o":
                    if question_id not in data_by_question_id:
                        data_by_question_id[question_id] = {
                            "question": question}
                    data_by_question_id[question_id][system] = answer
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON line: {line.strip()} - {e}")
                continue

    for question_id, data in data_by_question_id.items():
        if "MindSearch" in data:
            comparison_data = {"question": data.get(
                "question"), "reference_answer": data["MindSearch"]}
            if "ReAct" in data:
                comparison_data["ReAct_answer"] = data["ReAct"]
            if "CQ_Solver" in data:
                comparison_data["CQ_Solver_answer"] = data["CQ_Solver"]
            results[question_id] = comparison_data

    return results

# %%
import json
import os
from openai import OpenAI

import json
import os
from openai import OpenAI

def compare_answers_for_batch(filename="experiment_results.jsonl", output_batch_file="batch_input.jsonl"):
    """
    開啟 JSONL 檔案，針對相同的 question_id，準備 Batch API 的輸入檔案。
    使用 gpt-4o 且 system == "MindSearch" 的答案作為參考答案，
    評估 llama 3.3 70B 模型在不同系統下的答案。
    """
    batch_requests = []
    reference_answers = {}
    questions = {}

    with open(filename, 'r') as f:
        for line in f:
            try:
                record = json.loads(line.strip())
                question_id = record.get("question_id")
                question = record.get("question")
                system = record.get("system")
                model = record.get("model")
                answer = record.get("answer")

                if question_id:
                    questions[question_id] = question
                    if model == "gpt-4o" and system == "MindSearch":
                        reference_answers[question_id] = answer
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON line: {line.strip()} - {e}")
                continue

    with open(filename, 'r') as f:
        for line in f:
            try:
                record = json.loads(line.strip())
                question_id = record.get("question_id")
                system = record.get("system")
                model = record.get("model")
                answer = record.get("answer")

                if question_id and model == "llama 3.3 70B":
                    question = questions.get(question_id, "N/A")
                    reference_answer = reference_answers.get(question_id, "N/A")

                    if reference_answer != "N/A" and answer != "N/A":
                        eval_prompt_p2 = f"""Question: "{question}"
<Reference Answer>
{reference_answer}
</Reference Answer>

<AI assistant's answer>
{answer}
</AI assistant's answer>"""

                        batch_requests.append({
                            "custom_id": f"{question_id}-{system}-llama-3.3-70B",
                            "method": "POST",
                            "url": "/v1/chat/completions",
                            "body": {
                                "model": "gpt-4o",
                                "messages": [{"role": "developer", "content": eval_prompt_p1},
                                             {"role": "user", "content": eval_prompt_p2}]
                            }
                        })
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON line: {line.strip()} - {e}")
                continue

    # 將請求寫入 Batch 輸入檔案
    with open(output_batch_file, 'w') as f:
        for req in batch_requests:
            f.write(json.dumps(req) + '\n')

if __name__ == "__main__":
    client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))
    output_batch_file = "batch_input_llama.jsonl"
    # compare_answers_for_batch(output_batch_file=output_batch_file)
    # print(f"Batch input file created: {output_batch_file}")

    # 步驟 2: 上傳 Batch 輸入檔案
    try:
        with open(output_batch_file, "rb") as f:
            batch_input_file = client.files.create(
                file=f,
                purpose="batch"
            )
        print(f"Batch input file uploaded with ID: {batch_input_file.id}")
        input_file_id = batch_input_file.id

        # 步驟 3: 創建 Batch
        batch = client.batches.create(
            input_file_id=input_file_id,
            endpoint="/v1/chat/completions",
            completion_window="24h",
            metadata={"description": "Evaluation batch job for llama 3.3 70B"}
        )
        print(f"Batch created with ID: {batch.id}")

        # **後續步驟：輪詢狀態、檢索結果、解析和記錄結果**
        # 您需要實現這些步驟，就像之前的流程一樣。

    except Exception as e:
        print(f"Error during Batch API interaction: {e}")
# Out:
# Batch input file uploaded with ID: file-SGCN91hLjPgga6QnDukym7
# Batch created with ID: batch_67ffd0c550d08190b556a03fbedc3665

# %%
import json
import os
from openai import OpenAI

def prepare_cq_solver_re_evaluation_batch(cq_solver_results_file="experiment_results_2.jsonl",
                                          mindsearch_results_file="experiment_results.jsonl",
                                          output_batch_file="batch_input_cq_reEval.jsonl"):
    """
    準備 Batch API 輸入檔案，以重新評估 experiment_results_2.jsonl 中的 CQ_Solver 答案，
    並使用 experiment_results.jsonl 中對應的 MindSearch 答案作為參考。
    """
    batch_requests = []
    mindsearch_answers = {}
    cq_solver_data = {}

    # 載入 MindSearch 答案作為參考
    with open(mindsearch_results_file, 'r') as f_ms:
        for line in f_ms:
            try:
                record = json.loads(line.strip())
                if record.get("system") == "MindSearch" and record.get("model") == "gpt-4o" and record.get("question_id"):
                    mindsearch_answers[record["question_id"]] = record.get("answer")
            except json.JSONDecodeError as e:
                print(f"Error decoding MindSearch results: {e}")
                continue

    # 載入 CQ_Solver 的答案和問題
    with open(cq_solver_results_file, 'r') as f_cq:
        for line in f_cq:
            try:
                record = json.loads(line.strip())
                if record.get("system") == "CQ_Solver" and record.get("model") == "gpt-4o" and record.get("question_id"):
                    cq_solver_data[record["question_id"]] = {
                        "question": record.get("question"),
                        "answer": record.get("answer")
                    }
            except json.JSONDecodeError as e:
                print(f"Error decoding CQ_Solver results: {e}")
                continue

    # 準備 Batch API 請求
    for question_id, cq_solver_info in cq_solver_data.items():
        question = cq_solver_info.get("question", "N/A")
        cq_solver_answer = cq_solver_info.get("answer", "N/A")
        reference_answer = mindsearch_answers.get(question_id, "N/A")

        if cq_solver_answer != "N/A" and reference_answer != "N/A":
            eval_prompt_p2_cq_solver = f"""Question: "{question}"
<Reference Answer>
{reference_answer}
</Reference Answer>

<AI assistant's answer>
{cq_solver_answer}
</AI assistant's answer>"""
            batch_requests.append({
                "custom_id": f"{question_id}-cq-solver-re-eval",
                "method": "POST",
                "url": "/v1/chat/completions",
                "body": {
                    "model": "gpt-4o",
                    "messages": [{"role": "developer", "content": eval_prompt_p1},
                                 {"role": "user", "content": eval_prompt_p2_cq_solver}]
                }
            })

    # 將請求寫入 Batch 輸入檔案
    with open(output_batch_file, 'w') as f:
        for req in batch_requests:
            f.write(json.dumps(req) + '\n')

if __name__ == "__main__":
    client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))
    output_batch_file = "batch_input_cq_reEval.jsonl"
    # prepare_cq_solver_re_evaluation_batch(output_batch_file=output_batch_file)
    # print(f"Batch input file created: {output_batch_file}")

    # 步驟 2: 上傳 Batch 輸入檔案
    try:
        with open(output_batch_file, "rb") as f:
            batch_input_file = client.files.create(
                file=f,
                purpose="batch"
            )
        print(f"Batch input file uploaded with ID: {batch_input_file.id}")
        input_file_id = batch_input_file.id

        # 步驟 3: 創建 Batch
        batch = client.batches.create(
            input_file_id=input_file_id,
            endpoint="/v1/chat/completions",
            completion_window="24h",
            metadata={"description": "Re-evaluation batch job for CQ_Solver"}
        )
        print(f"Batch created with ID: {batch.id}")

        # **後續步驟：輪詢狀態、檢索結果、解析和記錄結果**
        # 您需要實現這些步驟，就像之前的流程一樣。

    except Exception as e:
        print(f"Error during Batch API interaction: {e}")

# %%
import json
import os
from openai import OpenAI

def compare_answers_for_batch_makeup(input_filenames, output_batch_file="batch_input_makeup.jsonl"):
    """
    開啟多個 JSONL 檔案，針對相同的 question_id，準備 Batch API 的輸入檔案。
    使用 gpt-4o 且 system == "MindSearch" 的答案作為參考答案，
    評估 llama 3.3 70B 模型在不同系統下的答案。
    如果 record.get("answer") is None，則略過該條記錄。

    Args:
        input_filenames (list): 包含輸入 JSONL 檔案名的列表。
        output_batch_file (str): 輸出 Batch API 輸入檔案名。
    """
    batch_requests = []
    reference_answers = {}
    questions = {}
    request_counter = 0

    # 第一次遍歷 experiment_results.jsonl 以收集參考答案和問題
    reference_filename = "experiment_results.jsonl"
    with open(reference_filename, 'r') as f_ref:
        for line in f_ref:
            try:
                record = json.loads(line.strip())
                question_id = record.get("question_id")
                question = record.get("question")
                system = record.get("system")
                model = record.get("model")
                answer = record.get("answer")

                if question_id and answer is not None:
                    questions[question_id] = question
                    if model == "gpt-4o" and system == "MindSearch":
                        reference_answers[question_id] = answer
            except json.JSONDecodeError as e:
                print(f"Error decoding JSON line in {reference_filename}: {line.strip()} - {e}")
                continue

    # 第二次遍歷輸入的 llama 模型結果檔案以準備評估請求
    for filename in input_filenames:
        with open(filename, 'r') as f_llama:
            for line in f_llama:
                try:
                    record = json.loads(line.strip())
                    question_id = record.get("question_id")
                    system = record.get("system")
                    model = record.get("model")
                    answer = record.get("answer")

                    if question_id and model == "llama 3.3 70B" and answer is not None:
                        question = questions.get(question_id, "N/A")
                        reference_answer = reference_answers.get(question_id, "N/A")

                        if reference_answer != "N/A":
                            eval_prompt_p2 = f"""User Question: "{question}"
<Reference Answer>
{reference_answer}
</Reference Answer>

<AI assistant's answer>
{answer}
</AI assistant's answer>"""

                            custom_id = f"{question_id}-{system}-llama-3.3-70B-{request_counter:05d}"
                            batch_requests.append({
                                "custom_id": custom_id,
                                "method": "POST",
                                "url": "/v1/chat/completions",
                                "body": {
                                    "model": "gpt-4o",
                                    "messages": [{"role": "developer", "content": eval_prompt_p1},
                                                 {"role": "user", "content": eval_prompt_p2}]
                                }
                            })
                            request_counter += 1
                except json.JSONDecodeError as e:
                    print(f"Error decoding JSON line in {filename}: {line.strip()} - {e}")
                    continue

    # 將請求寫入 Batch 輸入檔案
    with open(output_batch_file, 'w') as f:
        for req in batch_requests:
            f.write(json.dumps(req) + '\n')

if __name__ == "__main__":
    client = OpenAI(api_key=os.environ.get("OPENAI_API_KEY"))
    # input_filenames = ['llama_experiment_results_makeup_exam.jsonl', 'llama_experiment_results_makeup_exam2.jsonl']
    output_batch_file = "batch_input_llama_makeup.jsonl"
    # compare_answers_for_batch_makeup(input_filenames, output_batch_file=output_batch_file)
    # print(f"Batch input file created: {output_batch_file}")

    # 步驟 2: 上傳 Batch 輸入檔案
    try:
        with open(output_batch_file, "rb") as f:
            batch_input_file = client.files.create(
                file=f,
                purpose="batch"
            )
        print(f"Batch input file uploaded with ID: {batch_input_file.id}")
        input_file_id = batch_input_file.id

        # 步驟 3: 創建 Batch
        batch = client.batches.create(
            input_file_id=input_file_id,
            endpoint="/v1/chat/completions",
            completion_window="24h",
            metadata={"description": "Evaluation batch job for llama 3.3 70B"}
        )
        print(f"Batch created with ID: {batch.id}")

        # **後續步驟：輪詢狀態、檢索結果、解析和記錄結果**
        # 您需要實現這些步驟，就像之前的流程一樣。

    except Exception as e:
        print(f"Error during Batch API interaction: {e}")
# Out:
# Batch input file uploaded with ID: file-7TK6JChQSNGtP4kYKXKbWN
# Batch created with ID: batch_68009ccb03408190aa0c38c35c0e6b75

# %%
from openai import OpenAI
client = OpenAI()

batch = client.batches.retrieve("batch_68009ccb03408190aa0c38c35c0e6b75")
print(batch)
# Out:
# Batch(id='batch_68009ccb03408190aa0c38c35c0e6b75', completion_window='24h', created_at=1744870603, endpoint='/v1/chat/completions', input_file_id='file-7TK6JChQSNGtP4kYKXKbWN', object='batch', status='completed', cancelled_at=None, cancelling_at=None, completed_at=1744870782, error_file_id=None, errors=None, expired_at=None, expires_at=1744957003, failed_at=None, finalizing_at=1744870700, in_progress_at=1744870604, metadata={'description': 'Evaluation batch job for llama 3.3 70B'}, output_file_id='file-6VfPFHpsB1fP2e6GhS6MuL', request_counts=BatchRequestCounts(completed=491, failed=0, total=491))

# %%
from openai import OpenAI
client = OpenAI()

file_response = client.files.content("file-6VfPFHpsB1fP2e6GhS6MuL")
output_filename = "llama_makeup_evaluation_results.jsonl"
with open(output_filename, 'w') as outfile:
    outfile.write(file_response.text)
